# %%
run generate_window_files_general.py --data chruch_street
# Out:
# Start to wrtie file: chruch_street_window_file.txt
# Finish Writing

# %%
from data_info import data_info

# %%
import json

# %%
data = data_info["chruch_street"]
annotation = json.load(open(data["json_annotation"]))

# %%
data
# Out:
# {'data_path': '/root/data/data-chruch_street',
#  'img_path': '/root/data/data-chruch_street/images',
#  'json_annotation': '/root/data/data-chruch_street/annotations.json',
#  'name': 'chruch_street.mp4',
#  'testing': {'end_frame': 57022,
#   'frame_stride': 30,
#   'sets': [0],
#   'start_frame': 0,
#   'videos': [0]},
#  'training': {'end_frame': 30000,
#   'frame_stride': 1,
#   'sets': [0],
#   'start_frame': 0,
#   'videos': [0]}}

# %%
annotation
# Out:
# {u'50088': {u'302': {u'attributes': [],
#    u'height': 149,
#    u'occluded': 0,
#    u'outside': 0,
#    u'width': 47,
#    u'x1': 458,
#    u'y1': 193},
#   u'303': {u'attributes': [],
#    u'height': 121,
#    u'occluded': 0,
#    u'outside': 0,
#    u'width': 50,
#    u'x1': 523,
#    u'y1': 162},
#   u'304': {u'attributes': [],
#    u'height': 121,
#    u'occluded': 0,
#    u'outside': 0,
#    u'width': 47,
#    u'x1': 613,
#    u'y1': 166},
#   u'305': {u'attributes': [],
#    u'height': 53,
#    u'occluded': 0,
#    u'outside': 1,
#    u'width': 22,
#    u'x1': 380,
#    u'y1': 67},
#   u'306': {u'attributes': [],
#    u'height': 53,
#    u'occluded': 0,
#    u'outside': 1,
#    u'width': 21,
#    u'x1': 407,
#    u'y1': 64},
#   u'307': {u'attributes': [],
#    u'height': 57,
#    u'occluded': 0,
#    u'outside': 1,
#    u'width': 19,
#    u'x1': 435,
#    u'y1': 61},
#   u'308': {u'attributes': [],
#    u'height': 54,
#    u'occluded': 0,
#    u'outside': 1,
# ...

# %%
from PIL import Image
